# %%
import os
import pandas as pd
import numpy as np
import csv

# %%
df7 = pd.read_csv('market_7.csv',engine='python', header = 'infer', encoding = 'euc-kr')
df8 = pd.read_csv('market_8.csv',engine='python', header = 'infer', encoding = 'euc-kr')
df9 = pd.read_csv('market_9.csv',engine='python', header = 'infer', encoding = 'euc-kr')
df10 = pd.read_csv('market_10.csv',engine='python', header = 'infer', encoding = 'euc-kr')

# %%
df = pd.concat([df7,df8,df9,df10])

# %%
df.shape
# Out:
# (6940, 4)

# %%
df
# Out:
#       기준_년월_코드  상권_코드   상권_코드_명  총_유동인구_수
# 0       201807      1    가락로16길     12945
# 1       201807      2    가락로28길     37883
# 2       201807      3    가락로36길     25330
# 3       201807      4  가로공원로76길     53739
# 4       201807      5   가마산로12길     33914
# 5       201807      6   가마산로15길     25773
# 6       201807      7   가마산로61길     62311
# 7       201807      8   가마산로88길     18834
# 8       201807      9   가마산로89길     23145
# 9       201807     10     가산로3길     85880
# 10      201807     11     가산로5길     50321
# 11      201807     12     가산로7길     15168
# 12      201807     13   가재울로14길       763
# 13      201807     14    가재울로4길     42888
# 14      201807     15    가재울로6길     65800
# 15      201807     16    가좌로11길     37552
# 16      201807     17     가좌로6길     45041
# 17      201807     18     가좌로7길    114802
# 18      201807     19    가좌로7다길     73420
# 19      201807     20     가좌로9길     38613
# 20      201807     21     갈현로1길     34694
# ...

# %%
df.to_csv('building_code.csv',index=False, header=True, encoding = 'euc-kr')
